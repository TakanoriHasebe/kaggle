# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import correlation
# %matplotlib inline

# %%
movie_df = pd.read_csv("movies.csv")

# %%
df2 = pd.DataFrame()
movieid_dict = {}
movieid_dict_rev= {} 
for i, row in movie_df.iterrows():
    print(i, row)
    movieid_dict[i]  = row.movieId
    movieid_dict_rev[row.movieId] = i
# Out:
# 0 movieId                                              1
# title                                 Toy Story (1995)
# genres     Adventure|Animation|Children|Comedy|Fantasy
# Name: 0, dtype: object
# 1 movieId                             2
# title                  Jumanji (1995)
# genres     Adventure|Children|Fantasy
# Name: 1, dtype: object
# 2 movieId                          3
# title      Grumpier Old Men (1995)
# genres              Comedy|Romance
# Name: 2, dtype: object
# 3 movieId                           4
# title      Waiting to Exhale (1995)
# genres         Comedy|Drama|Romance
# Name: 3, dtype: object
# 4 movieId                                     5
# title      Father of the Bride Part II (1995)
# genres                                 Comedy
# Name: 4, dtype: object
# 5 movieId                        6
# title                Heat (1995)
# genres     Action|Crime|Thriller
# Name: 5, dtype: object
# 6 movieId                 7
# title      Sabrina (1995)
# ...

# %%
import pandas as pd
 
#DataFrameを生成するコード
data_frame = pd.DataFrame([['a', 1], ['b', 2], ['c', 3]], columns=['columnA', 'columnB'])
data_frame
# Out:
#   columnA  columnB
# 0       a        1
# 1       b        2
# 2       c        3

# %%
for i, row in data_frame.iterrows():
    print('')
    print(i)
    print(row)
# Out:
# 0
# columnA    a
# columnB    1
# Name: 0, dtype: object
#
# 1
# columnA    b
# columnB    2
# Name: 1, dtype: object
#
# 2
# columnA    c
# columnB    3
# Name: 2, dtype: object

# %%
userid_max = df['userId'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-006af1f40dba> in <module>()
# ----> 1 userid_max = df['userId'].max()
#
# NameError: name 'df' is not defined

# %%
df_max = data_frame['columnA'].max()
df_max
# Out:
# 'c'

# %%
movie_max = max(movieid_dict.keys())

# %%
d = {'key1': 1, 'key2': 2, 'key3': 3}

# %%
d_max = max(d.keys())

# %%
d_max
# Out:
# 'key3'

# %%
arr = np.array([[1,2],[3,4],[5,6]])

# %%
arr
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr[0][0]
# Out:
# 1
